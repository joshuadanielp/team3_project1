# %%
# Dependencies
import pandas as pd
import numpy as np

# Save file path to variable
metrotransit_csv = "TransitStopsBoardingsAndAlightings2019.csv"

# Read with Pandas
metrotransit_df = pd.read_csv(metrotransit_csv)
metrotransit_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d0fa5e2d8777> in <module>
#       7
#       8 # Read with Pandas
# ----> 9 metrotransit_df = pd.read_csv(metrotransit_csv)
#      10 metrotransit_df.head()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'TransitStopsBoardingsAndAlightings2019.csv' does not exist: b'TransitStopsBoardingsAndAlightings2019.csv'

# %%
Route_df = metrotransit_df.groupby("Route Type")
Route_df.count()
# Out:
#                      Provider  Route Type  Route Classification  Route  Dir  \
# City
# ANOKA                     192         192                   192    192  190
# APPLE VALLEY              541         541                   541    541  541
# ARDEN HILLS                37          37                    37     37   37
# BAYTOWN TOWNSHIP            3           3                     3      3    3
# BECKER                      6           6                     6      6    6
# ...                       ...         ...                   ...    ...  ...
# WAYZATA                    92          92                    92     92   92
# WEST SAINT PAUL           421         421                   421    421  421
# WHITE BEAR LAKE           139         139                   139    139  139
# WHITE BEAR TOWNSHIP        10          10                    10     10   10
# WOODBURY                   38          38                    38     38   38
#
#                      Site_id  Geo_Node_Name  Group ID  latitude  longitude  \
# City
# ANOKA                    192            192         0       192        192
# APPLE VALLEY             541            541        32       541        541
# ARDEN HILLS               37             37         0        37         37
# BAYTOWN TOWNSHIP           3              3         0         3          3
# BECKER                     6              6         0         6          6
# ...                      ...            ...       ...       ...        ...
# WAYZATA                   92             92         0        92         92
# WEST SAINT PAUL          421            421         0       421        421
# WHITE BEAR LAKE          139            139         0       139        139
# WHITE BEAR TOWNSHIP       10             10         0        10         10
# WOODBURY                  38             38         0        38         38
#
#                      ...  y-coordinate  Trips  Obs Trips  Schedule  Ons  Offs  \
# City                 ...
# ANOKA                ...           192    192        188       192  190   188
# APPLE VALLEY         ...           541    541         24       541   24    24
# ARDEN HILLS          ...            37     37         37        37   37    37
# BAYTOWN TOWNSHIP     ...             3      3          3         3    3     3
# BECKER               ...             6      6          0         6    0     0
# ...                  ...           ...    ...        ...       ...  ...   ...
# WAYZATA              ...            92     92         91        92   91    91
# WEST SAINT PAUL      ...           421    421        421       421  421   421
# WHITE BEAR LAKE      ...           139    139        139       139  139   139
# WHITE BEAR TOWNSHIP  ...            10     10         10        10   10    10
# WOODBURY             ...            38     38         38        38   38    38
#
#                      Seq  %Sampled  Downtown  Comment
# City
# ANOKA                192       192       192        0
# APPLE VALLEY         541       541       541        0
# ARDEN HILLS           37        37        37        0
# BAYTOWN TOWNSHIP       3         3         3        0
# BECKER                 6         6         6        0
# ...                  ...       ...       ...      ...
# WAYZATA               92        91        92        0
# WEST SAINT PAUL      421       421       421        1
# WHITE BEAR LAKE      139       139       139        0
# WHITE BEAR TOWNSHIP   10        10        10        0
# WOODBURY              38        38        38        0
#
# [94 rows x 21 columns]

# %%
# Route_df = metrotransit_df.groupby("Schedule")
Route_df.count()
# Out:
#                      Provider  Route Type  Route Classification  Route  Dir  \
# City
# ANOKA                     192         192                   192    192  190
# APPLE VALLEY              541         541                   541    541  541
# ARDEN HILLS                37          37                    37     37   37
# BAYTOWN TOWNSHIP            3           3                     3      3    3
# BECKER                      6           6                     6      6    6
# ...                       ...         ...                   ...    ...  ...
# WAYZATA                    92          92                    92     92   92
# WEST SAINT PAUL           421         421                   421    421  421
# WHITE BEAR LAKE           139         139                   139    139  139
# WHITE BEAR TOWNSHIP        10          10                    10     10   10
# WOODBURY                   38          38                    38     38   38
#
#                      Site_id  Geo_Node_Name  Group ID  latitude  longitude  \
# City
# ANOKA                    192            192         0       192        192
# APPLE VALLEY             541            541        32       541        541
# ARDEN HILLS               37             37         0        37         37
# BAYTOWN TOWNSHIP           3              3         0         3          3
# BECKER                     6              6         0         6          6
# ...                      ...            ...       ...       ...        ...
# WAYZATA                   92             92         0        92         92
# WEST SAINT PAUL          421            421         0       421        421
# WHITE BEAR LAKE          139            139         0       139        139
# WHITE BEAR TOWNSHIP       10             10         0        10         10
# WOODBURY                  38             38         0        38         38
#
#                      ...  y-coordinate  Trips  Obs Trips  Schedule  Ons  Offs  \
# City                 ...
# ANOKA                ...           192    192        188       192  190   188
# APPLE VALLEY         ...           541    541         24       541   24    24
# ARDEN HILLS          ...            37     37         37        37   37    37
# BAYTOWN TOWNSHIP     ...             3      3          3         3    3     3
# BECKER               ...             6      6          0         6    0     0
# ...                  ...           ...    ...        ...       ...  ...   ...
# WAYZATA              ...            92     92         91        92   91    91
# WEST SAINT PAUL      ...           421    421        421       421  421   421
# WHITE BEAR LAKE      ...           139    139        139       139  139   139
# WHITE BEAR TOWNSHIP  ...            10     10         10        10   10    10
# WOODBURY             ...            38     38         38        38   38    38
#
#                      Seq  %Sampled  Downtown  Comment
# City
# ANOKA                192       192       192        0
# APPLE VALLEY         541       541       541        0
# ARDEN HILLS           37        37        37        0
# BAYTOWN TOWNSHIP       3         3         3        0
# BECKER                 6         6         6        0
# ...                  ...       ...       ...      ...
# WAYZATA               92        91        92        0
# WEST SAINT PAUL      421       421       421        1
# WHITE BEAR LAKE      139       139       139        0
# WHITE BEAR TOWNSHIP   10        10        10        0
# WOODBURY              38        38        38        0
#
# [94 rows x 21 columns]

# %%
Trips = Route_df["Trips"]

Route_df = metrotransit_df.groupby("City")

city_df = Route_df[["City", "Trips", "Ons", "Offs"]]

# city_df = pd.DataFrame({"Trips": Trips})
# city_df.head()

df = pd.DataFrame(city_df, columns = ['Trips', 'Ons', 'Offs'])
df
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     499         result = _convert_object_array(
# --> 500             content, columns, dtype=dtype, coerce_float=coerce_float
#     501         )
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     582                 "{col:d} columns passed, passed data had "
# --> 583                 "{con} columns".format(col=len(columns), con=len(content))
#     584             )
#
# AssertionError: 3 columns passed, passed data had 2 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-87341e6d4c77> in <module>
#       8 # city_df.head()
#       9
# ---> 10 df = pd.DataFrame(city_df, columns = ['Trips', 'Ons', 'Offs'])
#      11 df
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     448                     if is_named_tuple(data[0]) and columns is None:
#     449                         columns = data[0]._fields
# --> 450                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     451                     columns = ensure_index(columns)
#     452
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     462         return [], []  # columns if columns is not None else []
#     463     if isinstance(data[0], (list, tuple)):
# --> 464         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     465     elif isinstance(data[0], abc.Mapping):
#     466         return _list_of_dict_to_arrays(
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     501         )
#     502     except AssertionError as e:
# --> 503         raise ValueError(e) from e
#     504     return result
#     505
#
# ValueError: 3 columns passed, passed data had 2 columns
