# %%
# JOSH
# 1. What are the most popular metro transit stations? Defined by volume of "ons" & "offs"
    # Img 1.1 is heatmap routes
    # Img 1.2 is heatmap w/ top 5 pins dropped on the map

# KARIM
# 2. What part of the week sees the highest level of metro transit traffic?
    # Img 2.1 is bar chart
    # Img 2.2 heatmap showing the highest level day (Saturday "ons")

# ZOEY
# 3. What is the relationship between station "ons" & "offs"
    # Img 3.1 scatterplot of single station "ons" vs. "offs"
    # Img 3.2 stasticial analysis 

# OPTIONAL -- IF WE GET TO IT    
# 4. Does the Vikings' success correlate to Lightrail traffic ("ons")?
    #

# %%
# %matplotlib notebook

# Dependencies
import gmaps
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# Save file path to variable
metrotransit_csv = "TransitStopsBoardingsAndAlightings2019.csv"

# Read with Pandas
metrotransit_df = pd.read_csv(metrotransit_csv)
metrotransit_df["Route Classification"].unique()
# Out:
# array(['Core Local', 'Supporting Local', 'Commuter Express', 'Special',
#        'Suburban Local', 'BRT', 'LRT', 'Commuter Rail', nan], dtype=object)

# %%
Route_df = metrotransit_df.groupby("Route Type")
Route_df.count()
# Out:
#                 Provider  Route Classification  Route    Dir  Site_id  \
# Route Type
# Express             7546                  7546   7546   7532     7546
# Suburban Local      8321                  8321   8321   8321     8321
# Urban Local        23252                 23252  23252  23126    23252
#
#                 Geo_Node_Name  Group ID  latitude  longitude  x-coordinate  \
# Route Type
# Express                  7546        93      7546       7546          7546
# Suburban Local           8321       228      8321       8321          8321
# Urban Local             23252       348     23252      23252         23252
#
#                 ...   City  Trips  Obs Trips  Schedule    Ons   Offs    Seq  \
# Route Type      ...
# Express         ...   7546   7546       5795      7546   5809   5795   7546
# Suburban Local  ...   8321   8321       6373      8321   6373   6373   8321
# Urban Local     ...  23252  23252      23093     23252  23093  22967  23252
#
#                 %Sampled  Downtown  Comment
# Route Type
# Express             6698      7546       38
# Suburban Local      8279      8321       71
# Urban Local        23252     23252      292
#
# [3 rows x 21 columns]

# %%
schedule_df = metrotransit_df.groupby("Schedule")
schedule_df.count()
# Out:
#           Provider  Route Type  Route Classification  Route    Dir  Site_id  \
# Schedule
# Saturday      9313        9313                  9313   9313   9271     9313
# Sunday        7496        7496                  7496   7496   7454     7496
# Weekday      22303       22303                 22303  22303  22254    22303
# Weekend          7           7                     7      7      0        7
#
#           Geo_Node_Name  Group ID  latitude  longitude  ...  y-coordinate  \
# Schedule                                                ...
# Saturday           9313       175      9313       9313  ...          9313
# Sunday             7496       152      7496       7496  ...          7496
# Weekday           22303       341     22303      22303  ...         22303
# Weekend               7         1         7          7  ...             7
#
#            City  Trips  Obs Trips    Ons   Offs    Seq  %Sampled  Downtown  \
# Schedule
# Saturday   9313   9313       8923   8923   8881   9313      9313      9313
# Sunday     7496   7496       7106   7106   7064   7496      7496      7496
# Weekday   22303  22303      19232  19239  19190  22303     21413     22303
# Weekend       7      7          0      7      0      7         7         7
#
#           Comment
# Schedule
# Saturday      100
# Sunday         73
# Weekday       228
# Weekend         0
#
# [4 rows x 21 columns]

# %%
core_local_df = metrotransit_df.loc[metrotransit_df["Route Classification"]=="Core Local"]
core_local_df.head()
# Out:
#         Provider   Route Type Route Classification Route   Dir  Site_id  \
# 0  Metro Transit  Urban Local           Core Local     2  East  51581.0
# 1  Metro Transit  Urban Local           Core Local     2  East   1099.0
# 2  Metro Transit  Urban Local           Core Local     2  East  13340.0
# 3  Metro Transit  Urban Local           Core Local     2  East  13337.0
# 4  Metro Transit  Urban Local           Core Local     2  East  56705.0
#
#                            Geo_Node_Name Group ID   latitude  longitude  ...  \
# 0  HENNEPIN AVE & FRANKLIN AVE / 22ND ST      NaN  44.961886 -93.292079  ...
# 1             HENNEPIN AVE S & 22ND ST W      NaN  44.961030 -93.292777  ...
# 2            DUPONT AVE & FRANKLIN AVE W      NaN  44.962534 -93.293016  ...
# 3        FRANKLIN AVE W & HENNEPIN AVE S      NaN  44.962630 -93.291123  ...
# 4         FRANKLIN AVE W & LYNDALE AVE S      NaN  44.962642 -93.287697  ...
#
#           City  Trips Obs Trips  Schedule  Ons Offs  Seq  %Sampled  Downtown  \
# 0  MINNEAPOLIS   92.0      92.0   Weekday   75  8.0  1.0      100%         N
# 1  MINNEAPOLIS   92.0      92.0   Weekday   33  2.0  2.0      100%         N
# 2  MINNEAPOLIS   92.0      92.0   Weekday   17  1.0  3.0      100%         N
# 3  MINNEAPOLIS   92.0      92.0   Weekday  177  2.0  4.0      100%         N
# 4  MINNEAPOLIS   92.0      92.0   Weekday  143  4.0  5.0      100%         N
#
#   Comment
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
# [5 rows x 22 columns]

# %%
sample_core_local_df = core_local_df.sample(n = 50)

ons = sample_core_local_df["Ons"]
offs = sample_core_local_df["Offs"]

plt.scatter(ons, offs, marker="o", facecolors="red", edgecolors="black")
plt.xlabel("Ons")
plt.ylabel("Offs")
plt.show
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Store latitude and longitude in locations
locations = core_local_df[["latitude", "longitude"]].astype(float)

# Fill NaN values and convert to float
volume = core_local_df["Ons"].astype(float)

# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=volume, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=.0012)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Correlation analysis comparing "ons" & "offs" for Core Local Routes

# %%
# ID top five ons

core_local_df = pd.DataFrame(metrotransit_df,columns=["Geo_Node_Name","Ons","Offs","latitude", "longitude"])
core_local_df = core_local_df.dropna()
core_local_df["Ons"] = core_local_df["Ons"].str.replace(',', '')
core_local_df["Ons"] = core_local_df["Ons"].astype(int)

# core_local_on_df = core_local_df.sort_values(by="Ons",ascending=False)
# core_local_on_df.head()

core_local_top5ons = core_local_df.nlargest(5,["Ons"])
core_local_top5ons
# Out:
#                   Geo_Node_Name   Ons   Offs   latitude  longitude
# 22223    7TH & NICOLLET STATION  1061  124.0  44.977311 -93.273066
# 83     PLEASANT ST & JONES HALL   938  108.0  44.978407 -93.235333
# 3167   NICOLLET MALL & 7TH ST S   898  107.0  44.977120 -93.272189
# 6189      5TH ST & MINNESOTA ST   750   34.0  44.946749 -93.092106
# 31543    7TH & NICOLLET STATION   731   73.0  44.977311 -93.273066

# %%
# ID top five offs
core_local_top5offs = core_local_df.nlargest(5,["Offs"])
core_local_top5offs
# Out:
#                               Geo_Node_Name  Ons   Offs   latitude  longitude
# 3157               NICOLLET MALL & 7TH ST S   82  930.0  44.976718 -93.272273
# 22257              6TH ST S & NICOLLET MALL   66  930.0  44.977888 -93.271671
# 929    CHICAGO LAKE TRANSIT CENTER & GATE A  357  850.0  44.949243 -93.262056
# 20170     MAPLE GROVE P&R & TRANSIT STATION   12  812.0  45.091409 -93.436758
# 21546            FOLEY P&R & EVERGREEN BLVD   15  800.0  45.142338 -93.285538

# %%
# Pins on the map to answer what are the most popular "ons" & "offs"

info_box_template = """
<dl>
<dt>Name</dt><dd>{Geo_Node_Name}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
top5_ons_df = [info_box_template.format(**row) for index, row in core_local_top5ons.iterrows()]
top5_pins = core_local_top5ons[["latitude", "longitude"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(top5_pins, info_box_content=top5_ons_df)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
LRT_df = metrotransit_df.loc[metrotransit_df["Route Classification"]=="LRT"]
LRT_df.head()
# Out:
#             Provider   Route Type Route Classification      Route  Dir  \
# 22201  Metro Transit  Urban Local                  LRT  Blue Line  NaN
# 22202  Metro Transit  Urban Local                  LRT  Blue Line  NaN
# 22203  Metro Transit  Urban Local                  LRT  Blue Line  NaN
# 22204  Metro Transit  Urban Local                  LRT  Blue Line  NaN
# 22205  Metro Transit  Urban Local                  LRT  Blue Line  NaN
#
#        Site_id                   Geo_Node_Name Group ID   latitude  longitude  \
# 22201  51405.0             MOA TRANSIT STATION     MAAM  44.854277 -93.238877
# 22202  51437.0                28TH AVE STATION      NaN  44.855876 -93.231499
# 22203  51436.0     BLOOMINGTON CENTRAL STATION      NaN  44.856369 -93.226485
# 22204  53280.0  AMERICAN BLVD 34TH AVE STATION      NaN  44.859536 -93.223109
# 22205  51435.0     TERMINAL 2 HUMPHREY STATION      NaN  44.874119 -93.224068
#
#        ...           City  Trips Obs Trips  Schedule    Ons Offs  Seq  \
# 22201  ...    BLOOMINGTON  220.0     220.0   Weekday  2,686  NaN  1.0
# 22202  ...    BLOOMINGTON  220.0     220.0   Weekday  1,000  NaN  2.0
# 22203  ...    BLOOMINGTON  220.0     220.0   Weekday    229  NaN  3.0
# 22204  ...    BLOOMINGTON  220.0     220.0   Weekday    269  NaN  4.0
# 22205  ...  FORT SNELLING  221.0     221.0   Weekday  2,250  NaN  5.0
#
#        %Sampled  Downtown                  Comment
# 22201      100%         N  New MOA transit station
# 22202      100%         N                      NaN
# 22203      100%         N                      NaN
# 22204      100%         N                      NaN
# 22205      100%         N                      NaN
#
# [5 rows x 22 columns]

# %%
LRT_clean_df = LRT_df.dropna()
LRT_clean_df["Ons"] = LRT_clean_df["Ons"].str.replace(",", "")
# LRT_clean_df["Ons"] = LRT_clean_df["Ons"].astype(int)

# Store latitude and longitude in locations
locations_LRT = LRT_clean_df[["latitude", "longitude"]].astype(float)

# Fill NaN values and convert to float
volume = LRT_clean_df["Ons"].astype(float)

# Plot Heatmap
fig_LRT = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations_LRT, weights=volume, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=.0013)


# Add layer
fig_LRT.add_layer(heat_layer)

# Display figure
fig_LRT
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# <ipython-input-14-3b1b408d1483> in <module>
#      15 heat_layer = gmaps.heatmap_layer(locations_LRT, weights=volume,
#      16                                  dissipating=False, max_intensity=10,
# ---> 17                                  point_radius=.0013)
#      18
#      19
#
# ~\Anaconda3\lib\site-packages\gmaps\heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     267     )
#     268     if is_weighted:
# --> 269         return WeightedHeatmap(**widget_args)
#     270     else:
#     271         return Heatmap(**widget_args)
#
# ~\Anaconda3\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in __init__(self, *args, **kwargs)
#     995             for key, value in kwargs.items():
#     996                 if self.has_trait(key):
# --> 997                     setattr(self, key, value)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# ~\Anaconda3\lib\site-packages\gmaps\geotraitlets.py in validate(self, obj, value)
#      27             _validate_latitude(latitude)
#      28             _validate_longitude(longitude)
# ---> 29         return super(LocationArray, self).validate(obj, locations_as_list)
#      30
#      31
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in validate(self, obj, value)
#    2322
#    2323     def validate(self, obj, value):
# -> 2324         value = super(List, self).validate(obj, value)
#    2325         value = self.validate_elements(obj, value)
#    2326         return value
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in validate(self, obj, value)
#    2240             return value
#    2241
# -> 2242         value = self.validate_elements(obj, value)
#    2243
#    2244         return value
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in validate_elements(self, obj, value)
#    2317         length = len(value)
#    2318         if length < self._minlen or length > self._maxlen:
# -> 2319             self.length_error(obj, value)
#    2320
#    2321         return super(List, self).validate_elements(obj, value)
#
# ~\Anaconda3\lib\site-packages\traitlets\traitlets.py in length_error(self, obj, value)
#    2312         e = "The '%s' trait of %s instance must be of length %i <= L <= %i, but a value of %s was specified." \
#    2313             % (self.name, class_of(obj), self._minlen, self._maxlen, value)
# -> 2314         raise TraitError(e)
#    2315
#    2316     def validate_elements(self, obj, value):
#
# TraitError: The 'locations' trait of a WeightedHeatmap instance must be of length 1 <= L <= 9223372036854775807, but a value of [] was specified.
